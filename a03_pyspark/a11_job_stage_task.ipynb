# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
spark = SparkSession.builder.master("local[5]")\
        .appName("testing")\
        .getOrCreate()
# Out:
# 25/05/18 16:44:02 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/05/18 16:44:02 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.102.70:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[5]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>testing</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
employee_df=spark.read.format("csv")\
            .option("header", "true")\
            .load("data/employee_data.csv")

print(employee_df.rdd.getNumPartitions())
employee_df = employee_df.repartition(2)
print(employee_df.rdd.getNumPartitions())
employee_df=employee_df.filter(col("Salary")>90000)\
        .select("id", "name", "age", "salary")\
        .groupby("age").count()

employee_df.collect()
# Out:
# 1
# 2
# [Row(age='31', count=1), Row(age='23', count=1)]

# %%
# spark.stop()
