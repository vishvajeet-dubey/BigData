// %% [markdown]
// - Below command used for almond kernal installation in powershell
// - scala version= 2.12.11
//
// ```
// coursier launch --use-bootstrap almond:0.10.0 --scala 2.12.11 -- --install
// ```

// %%
import $ivy.`org.apache.spark:spark-core_2.12:3.5.3`
import $ivy.`org.apache.spark:spark-sql_2.12:3.5.3`
import org.apache.spark.sql.SparkSession
import org.apache.spark.sql.functions._
import org.apache.spark.sql.DataFrame
// Out:
// import $ivy.$
//
// import $ivy.$
//
// import org.apache.spark.sql.SparkSession
//
// import org.apache.spark.sql.functions._
//
// import org.apache.spark.sql.DataFrame

// %%
val spark = SparkSession.builder()
  .appName("AlmondSparkNotebook")
  .master("local[*]")
  .getOrCreate()

spark.sparkContext.setLogLevel("ERROR") // for disable the logging
 
import spark.implicits._
// Out:
// Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
// 25/10/28 16:00:37 INFO SparkContext: Running Spark version 3.5.3
// 25/10/28 16:00:37 INFO SparkContext: OS info Windows 10, 10.0, amd64
// 25/10/28 16:00:37 INFO SparkContext: Java version 11.0.29
// 25/10/28 16:00:38 INFO ResourceUtils: ==============================================================
// 25/10/28 16:00:38 INFO ResourceUtils: No custom resources configured for spark.driver.
// 25/10/28 16:00:38 INFO ResourceUtils: ==============================================================
// 25/10/28 16:00:38 INFO SparkContext: Submitted application: AlmondSparkNotebook
// 25/10/28 16:00:38 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
// 25/10/28 16:00:38 INFO ResourceProfile: Limiting resource is cpu
// 25/10/28 16:00:38 INFO ResourceProfileManager: Added ResourceProfile id: 0
// 25/10/28 16:00:38 INFO SecurityManager: Changing view acls to: VishvaPC
// 25/10/28 16:00:38 INFO SecurityManager: Changing modify acls to: VishvaPC
// 25/10/28 16:00:38 INFO SecurityManager: Changing view acls groups to:
// 25/10/28 16:00:38 INFO SecurityManager: Changing modify acls groups to:
// 25/10/28 16:00:38 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: VishvaPC; groups with view permissions: EMPTY; users with modify permissions: VishvaPC; groups with modify permissions: EMPTY
// 25/10/28 16:00:40 INFO Utils: Successfully started service 'sparkDriver' on port 51021.
// 25/10/28 16:00:40 INFO SparkEnv: Registering MapOutputTracker
// 25/10/28 16:00:40 INFO SparkEnv: Registering BlockManagerMaster
// 25/10/28 16:00:40 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
// 25/10/28 16:00:40 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
// 25/10/28 16:00:40 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
// 25/10/28 16:00:40 INFO DiskBlockManager: Created local directory at C:\Users\VishvaPC\AppData\Local\Temp\blockmgr-77d8ac56-a8a5-4863-a5d1-2b87e3bf2605
// 25/10/28 16:00:40 INFO MemoryStore: MemoryStore started with capacity 1645.2 MiB
// 25/10/28 16:00:41 INFO SparkEnv: Registering OutputCommitCoordinator
// 25/10/28 16:00:41 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
// 25/10/28 16:00:41 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
// 25/10/28 16:00:41 INFO Utils: Successfully started service 'SparkUI' on port 4041.
// 25/10/28 16:00:42 INFO Executor: Starting executor ID driver on host DESKTOP-FIP7IGL
// 25/10/28 16:00:42 INFO Executor: OS info Windows 10, 10.0, amd64
// 25/10/28 16:00:42 INFO Executor: Java version 11.0.29
// 25/10/28 16:00:42 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
// 25/10/28 16:00:42 INFO Executor: Created or updated repl class loader org.apache.spark.util.MutableURLClassLoader@27fe7946 for default.
// 25/10/28 16:00:42 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 51044.
// 25/10/28 16:00:42 INFO NettyBlockTransferService: Server created on DESKTOP-FIP7IGL:51044
// 25/10/28 16:00:42 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
// 25/10/28 16:00:42 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, DESKTOP-FIP7IGL, 51044, None)
// 25/10/28 16:00:42 INFO BlockManagerMasterEndpoint: Registering block manager DESKTOP-FIP7IGL:51044 with 1645.2 MiB RAM, BlockManagerId(driver, DESKTOP-FIP7IGL, 51044, None)
// 25/10/28 16:00:42 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, DESKTOP-FIP7IGL, 51044, None)
// 25/10/28 16:00:42 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, DESKTOP-FIP7IGL, 51044, None)
// spark: SparkSession = org.apache.spark.sql.SparkSession@49758ffd
// import spark.implicits._

// %%
val df = spark.range(100).toDF("number")
// Out:
// df: DataFrame = [number: bigint]

// %%
df.withColumn("evenOdd", when(col("number") % 2 === 0, "even").otherwise("odd")).groupBy("evenOdd").count().show()
// Out:
// +-------+-----+
// |evenOdd|count|
// +-------+-----+
// |   even|   50|
// |    odd|   50|
// +-------+-----+

// %%
spark.stop()
